# %%
from day5 import part1, part2

print(f"Part 1 Answer: {part1('input.txt')}")
print(f"Part 2 Answer: {part2('input.txt')}")
# Out:
# Part 1 Answer: 758
# Part 2 Answer: 343143696885053

# %%
#317945117476793 is too low
#320888169006666 is too low
