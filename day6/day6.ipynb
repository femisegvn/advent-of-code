# %%
from day6 import part1, part2

print(f"Part 1 Answer: {part1('input.txt')}")
print(f"Part 2 Answer: {part2('input.txt')}")
# Out:
# Part 1 Answer: 6172481852142
# Part 2 Answer: 10188206723429
